# %%
import pandas as pd

# %%
df=pd.read_csv("Boston.csv")
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
x=df.iloc[:,0:13]
y=df.iloc[:,-1]

# %%
x
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()

mms.fit(x_train)
x_train=mms.transform(x_train)
x_test=mms.transform(x_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model=Sequential()

model.add(Dense(128, activation='relu', name='Input'))
model.add(Dense(64,activation='relu', name='hidden'))
model.add(Dense(1,activation='linear', name='dense_output'))

# %%
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ Input (Dense)                        │ (None, 128)                 │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ hidden (Dense)                       │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_output (Dense)                 │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 10,113 (39.50 KB)
#  Trainable params: 10,113 (39.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(x_train, y_train, epochs=10, validation_split=0.05, verbose = 1)
# Out:
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 38.4926 - mae: 4.2883 - val_loss: 31.7330 - val_mae: 3.2797
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 36.8023 - mae: 4.2303 - val_loss: 31.3201 - val_mae: 3.1898
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 39.1114 - mae: 4.2845 - val_loss: 29.5173 - val_mae: 3.2210
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 32.0651 - mae: 3.9268 - val_loss: 28.8342 - val_mae: 3.0646
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 34.3107 - mae: 3.7789 - val_loss: 27.2713 - val_mae: 3.0330
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 27.4535 - mae: 3.6418 - val_loss: 26.0103 - val_mae: 2.9858
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 26.0983 - mae: 3.5857 - val_loss: 25.2156 - val_mae: 2.9404
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 21.5445 - mae: 3.2943 - val_loss: 24.5276 - val_mae: 3.0379
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 29.4223 - mae: 3.7049 - val_loss: 23.4886 - val_mae: 2.8852
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 27.5980 - mae: 3.3818 - val_loss: 22.9009 - val_mae: 2.8845

# %%
y_pred=model.predict(x_test)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step

# %%
y_pred
# Out:
# array([[ 7.8363123],
#        [27.680212 ],
#        [37.586292 ],
#        [22.166428 ],
#        [32.47998  ],
#        [26.170809 ],
#        [18.24433  ],
#        [17.366035 ],
#        [28.88786  ],
#        [20.1169   ],
#        [29.116415 ],
#        [19.203222 ],
#        [22.35014  ],
#        [34.907284 ],
#        [19.998919 ],
#        [13.833599 ],
#        [19.392931 ],
#        [33.89566  ],
#        [30.704536 ],
#        [16.211082 ],
#        [34.281116 ],
#        [17.655966 ],
#        [27.071161 ],
#        [22.239485 ],
#        [34.01319  ],
#        [16.988255 ],
#        [28.929003 ],
#        [20.183134 ],
#        [19.688822 ],
#        [23.993284 ],
#        [37.942757 ],
#        [10.872622 ],
#        [14.534046 ],
#        [32.902485 ],
#        [ 8.9959545],
#        [26.722818 ],
#        [10.498129 ],
#        [26.126825 ],
#        [18.110712 ],
#        [ 9.532061 ],
#        [13.159404 ],
#        [23.585938 ],
#        [31.216486 ],
#        [21.399237 ],
#        [10.9161825],
#        [28.507841 ],
#        [11.548676 ],
#        [22.681532 ],
#        [12.035864 ],
#        [14.135207 ],
#        [ 8.185791 ],
#        [12.616879 ],
#        [25.280708 ],
#        [18.402182 ],
#        [43.942486 ],
#        [19.423317 ],
#        [21.903513 ],
#        [14.69337  ],
#        [16.087175 ],
#        [21.945005 ],
#        [20.653807 ],
#        [26.545444 ],
#        [19.937956 ],
#        [17.731281 ],
#        [16.333408 ],
#        [15.4630165],
#        [23.003511 ],
#        [11.38606  ],
#        [18.32411  ],
#        [14.506774 ],
#        [20.37871  ],
#        [21.347605 ],
#        [21.364502 ],
#        [26.587473 ],
#        [ 9.829222 ],
#        [29.47722  ],
#        [26.81982  ],
#        [33.51851  ],
#        [16.888885 ],
#        [25.512087 ],
#        [15.074417 ],
#        [34.281296 ],
#        [28.832846 ],
#        [25.175974 ],
#        [18.08261  ],
#        [20.056107 ],
#        [25.120504 ],
#        [31.907557 ],
#        [37.61901  ],
#        [15.501469 ],
#        [30.20436  ],
#        [16.3761   ],
#        [17.430935 ],
#        [12.44585  ],
#        [21.353518 ],
#        [26.188562 ],
#        [21.030268 ],
#        [31.926405 ],
#        [28.16413  ],
#        [11.667132 ],
#        [31.222872 ],
#        [27.510096 ],
#        [19.553553 ],
#        [32.964546 ],
#        [18.738562 ],
#        [17.212425 ],
#        [30.628979 ],
#        [37.980637 ],
#        [30.565512 ],
#        [20.626238 ],
#        [20.606733 ],
#        [25.851103 ],
#        [19.897715 ],
#        [20.348192 ],
#        [23.45492  ],
#        [22.197794 ],
#        [24.255465 ],
#        [23.111132 ],
#        [30.11529  ],
#        [18.818832 ],
#        [13.824342 ],
#        [21.37137  ],
#        [16.354332 ],
#        [15.563229 ],
#        [26.534433 ],
#        [26.216667 ],
#        [18.403826 ],
#        [21.715548 ],
#        [24.80134  ],
#        [33.14517  ],
#        [21.852385 ],
#        [19.785938 ],
#        [38.761654 ],
#        [16.954275 ],
#        [30.971003 ],
#        [24.262648 ],
#        [22.570093 ],
#        [24.326643 ],
#        [19.650476 ],
#        [25.332815 ],
#        [20.357386 ],
#        [27.29063  ],
#        [12.548924 ],
#        [25.792664 ],
#        [28.023764 ],
#        [10.055292 ],
#        [24.312006 ],
#        [18.551104 ],
#        [12.321419 ],
#        [18.929392 ],
#        [15.773623 ],
#        [17.929552 ]], dtype=float32)
